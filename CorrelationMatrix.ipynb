# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import math
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### Read data into DFs

# %%
# 1. Column names (15 features + label)
headers = [
    'age',
    'workclass',
    'fnlwgt',
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country',
    'pred'   # label (<=50K / >50K)
]

# 2. Read raw data
original_train_df = pd.read_csv(
    "census-income.data.csv",
    header=None,
    names=headers,
    index_col=False
)

original_test_df = pd.read_csv(
    "census-income.test.csv",
    header=None,
    names=headers,
    index_col=False
)

# Work on copies
train_df = original_train_df.copy()
test_df = original_test_df.copy()

train_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country    pred
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
test_df.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country     pred
# 0             0              40   United-States   <=50K.
# 1             0              50   United-States   <=50K.
# 2             0              40   United-States    >50K.
# 3             0              40   United-States    >50K.
# 4             0              30   United-States   <=50K.

# %%
#strip whitespace

def data_to_str(df):
    """
    Strip leading/trailing spaces from all string (object) columns.
    """
    str_cols = df.select_dtypes(include=['object']).columns
    for col in str_cols:
        df[col] = df[col].str.strip()
    return df

# Apply to both train and test
train_df = data_to_str(train_df)
test_df = data_to_str(test_df)

# %%
train_df['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
test_df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
# Fix test set label: removing the period --- <=50K. → <=50K

test_df['pred'].value_counts()   # before

# Remove trailing period if present
test_df['pred'] = test_df['pred'].str.rstrip('.')

test_df['pred'].value_counts()   # after
# Out:
# pred
# <=50K    12435
# >50K      3846
# Name: count, dtype: int64

# %%
#turn "?" into missing values in both sets

train_df.replace("?", pd.NA, inplace=True)

# %%
# Convert "?" to missing values (NaN) in both dataframes
train_df.replace("?", np.nan, inplace=True)
test_df.replace("?", np.nan, inplace=True)

# Sanity check: how many missing values per column?
train_df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# pred                 0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# pred                0
# dtype: int64

# %%
# Before dropping
print("Train shape before dropping NaN:", train_df.shape)
print("Test shape before dropping NaN:", test_df.shape)
# Out:
# Train shape before dropping NaN: (32561, 15)
# Test shape before dropping NaN: (16281, 15)

# %%
# Drop rows with any NaN
train_df = train_df.dropna()
test_df = test_df.dropna()

# After dropping
print("Train shape after dropping NaN:", train_df.shape)
print("Test shape after dropping NaN:", test_df.shape)
# Out:
# Train shape after dropping NaN: (30162, 15)
# Test shape after dropping NaN: (15060, 15)

# %%
#convert numeric columns to integer types

def data_to_int32(df):
    """
    Convert known numeric columns to int32 (or Int64 if you want to allow NaN).
    """
    int_cols = [
        'age',
        'fnlwgt',
        'education-num',
        'capital-gain',
        'capital-loss',
        'hours-per-week'
    ]
    for col in int_cols:
        df[col] = df[col].astype('int32')
    return df

train_df = data_to_int32(train_df)
test_df = data_to_int32(test_df)

train_df.dtypes
# Out:
# age                int32
# workclass         object
# fnlwgt             int32
# education         object
# education-num      int32
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int32
# capital-loss       int32
# hours-per-week     int32
# native-country    object
# pred              object
# dtype: object

# %%
#removing duplicate rows

print("Train duplicates:", train_df.duplicated().sum())
print("Test duplicates:", test_df.duplicated().sum())

train_df = train_df.drop_duplicates()
test_df = test_df.drop_duplicates()

print("Train shape after dedup:", train_df.shape)
print("Test shape after dedup:", test_df.shape)
# Out:
# Train duplicates: 23
# Test duplicates: 5
# Train shape after dedup: (30139, 15)
# Test shape after dedup: (15055, 15)

# %% [markdown]
# # Recategorize the Categorical features into more meaningful groups

# %%
workclass_mapping = {
    'State-gov':'Government',
    'Local-gov':'Government',
    'Federal-gov':'Government',
    'Self-emp-inc':'Entrepreneur',
    'Self-emp-not-inc':'Entrepreneur',
    'Without-pay':'Unemployed',
    'Never-worked':'Unemployed',
    'Private':'Private',
    np.nan:'Unknown'
}

# Apply mapping and insert into dataframe
train_df.insert(2,'workclass-cat',train_df['workclass'].map(workclass_mapping))

edu_mapping = {
    'Preschool':'HS-dropout',
    '1st-4th':'HS-dropout',
    '5th-6th':'HS-dropout',
    '7th-8th':'HS-dropout',
    '9th':'HS-dropout',
    '10th':'HS-dropout',
    '11th':'HS-dropout',
    '12th':'HS-dropout',
    'HS-grad':'HS-grad',
    'Some-college':'Some-college',
    'Assoc-acdm':'Some-college',
    'Assoc-voc':'Some-college',
    'Bachelors':'Bachelors',
    'Masters':'Advanced-degree',
    'Prof-school':'Advanced-degree',
    'Doctorate':'Advanced-degree',
    np.nan:'Unknown'
}

train_df.insert(4,"education-cat",train_df['education'].map(edu_mapping))

marital_mapping = {
    'Never-married':'Single/Unmarried',
    'Divorced':'Single/Unmarried',
    'Separated':'Single/Unmarried',
    'Widowed':'Single/Unmarried',
    'Married-spouse-absent':'Single/Unmarried',
    'Married-civ-spouse':'Married',
    'Married-AF-spouse':'Married',
    np.nan:'Unknown'
}

train_df.insert(7,'marital-cat',train_df['marital-status'].map(marital_mapping))

occupation_mapping = {
    'Exec-managerial':'White-collar',
    'Prof-specialty':'White-collar',
    'Tech-support':'White-collar',
    
    'Other-service':'Service',
    'Sales':'Service',
    'Adm-clerical':'Service',
    'Protective-serv':'Service',
    
    'Craft-repair':'Blue-collar',
    'Transport-moving':'Blue-collar',
    'Machine-op-inspct':'Blue-collar',

    'Armed-Forces':'Military',

    'Priv-house-serv':'Manual',
    'Farming-fishing':'Manual',
    'Handlers-cleaners':'Manual',

    np.nan:'Unknown'
}

train_df.insert(10,'occupation-cat',train_df['occupation'].map(occupation_mapping))

train_df.insert(18,'native_imm_cat',pd.Series(np.where(train_df['native-country'] == 'United-States', 'Native', 'Immigrant')))

# drop all adjusted categorical features in favor of their derived categories
train_df.drop(['workclass','fnlwgt','education','education-num','marital-status','occupation','native-country'], axis = 1, inplace = True)

# %%
train_df
# Out:
#        age workclass-cat education-cat       marital-cat occupation-cat  \
# 0       39    Government     Bachelors  Single/Unmarried        Service
# 1       50  Entrepreneur     Bachelors           Married   White-collar
# 2       38       Private       HS-grad  Single/Unmarried         Manual
# 3       53       Private    HS-dropout           Married         Manual
# 4       28       Private     Bachelors           Married   White-collar
# ...    ...           ...           ...               ...            ...
# 32556   27       Private  Some-college           Married   White-collar
# 32557   40       Private       HS-grad           Married    Blue-collar
# 32558   58       Private       HS-grad  Single/Unmarried        Service
# 32559   22       Private       HS-grad  Single/Unmarried        Service
# 32560   52  Entrepreneur       HS-grad           Married   White-collar
#
#         relationship   race     sex  capital-gain  capital-loss  \
# 0      Not-in-family  White    Male          2174             0
# 1            Husband  White    Male             0             0
# 2      Not-in-family  White    Male             0             0
# 3            Husband  Black    Male             0             0
# 4               Wife  Black  Female             0             0
# ...              ...    ...     ...           ...           ...
# 32556           Wife  White  Female             0             0
# 32557        Husband  White    Male             0             0
# 32558      Unmarried  White  Female             0             0
# 32559      Own-child  White    Male             0             0
# 32560           Wife  White  Female         15024             0
#
#        hours-per-week native_imm_cat   pred
# 0                  40         Native  <=50K
# 1                  13         Native  <=50K
# 2                  40         Native  <=50K
# 3                  40         Native  <=50K
# 4                  40      Immigrant  <=50K
# ...               ...            ...    ...
# 32556              38            NaN  <=50K
# 32557              40            NaN   >50K
# 32558              40            NaN  <=50K
# 32559              20            NaN  <=50K
# 32560              40            NaN   >50K
#
# [30139 rows x 13 columns]

# %%
#OHE for numerical features only

# Select numeric columns only
numeric_df = train_df.select_dtypes(include=['int32', 'int64', 'float64'])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
#OHE for correlation matrix

# One-hot encode categorical features
encoded_df = pd.get_dummies(train_df.drop(columns=['pred']), drop_first=True)

# Add encoded label for correlation study
encoded_df['target'] = train_df['pred'].apply(lambda x: 1 if x == '>50K' else 0)

corr = encoded_df.corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Full Correlation Matrix (After One-Hot Encoding)")
plt.show()

# %%
print(corr)
# Out:
#                                    age  capital-gain  capital-loss  \
# age                           1.000000      0.080162      0.060141
# capital-gain                  0.080162      1.000000     -0.032255
# capital-loss                  0.060141     -0.032255      1.000000
# hours-per-week                0.101348      0.080429      0.052380
# workclass-cat_Government      0.086077     -0.016831      0.013589
# workclass-cat_Private        -0.210427     -0.048138     -0.036302
# workclass-cat_Unemployed      0.015340     -0.001760     -0.004714
# education-cat_Bachelors       0.006877      0.038892      0.032772
# education-cat_HS-dropout     -0.009502     -0.041055     -0.032291
# education-cat_HS-grad         0.010709     -0.047256     -0.030296
# education-cat_Some-college   -0.092806     -0.042618     -0.022867
# marital-cat_Single/Unmarried -0.307341     -0.084153     -0.081016
# occupation-cat_Manual        -0.047556     -0.028218     -0.027922
# occupation-cat_Military      -0.010818     -0.002549      0.005180
# occupation-cat_Service       -0.105613     -0.042745     -0.040577
# occupation-cat_White-collar   0.121145      0.103373      0.072943
# relationship_Not-in-family   -0.023759     -0.026510     -0.018268
# relationship_Other-relative  -0.069409     -0.020193     -0.014539
# relationship_Own-child       -0.420651     -0.052365     -0.050845
# relationship_Unmarried        0.049758     -0.028824     -0.040967
# relationship_Wife             0.024525      0.015568      0.014945
# race_Asian-Pac-Islander      -0.007847      0.005026      0.001447
# race_Black                   -0.014038     -0.021141     -0.025522
# race_Other                   -0.032393     -0.000382     -0.008289
# race_White                    0.027281      0.016955      0.026230
# sex_Male                      0.081827      0.048819      0.047008
# native_imm_cat_Native         0.001417      0.007255     -0.000608
# target                        0.242017      0.221204      0.150026
#
#                               hours-per-week  workclass-cat_Government  \
# age                                 0.101348                  0.086077
# capital-gain                        0.080429                 -0.016831
# capital-loss                        0.052380                  0.013589
# hours-per-week                      1.000000                 -0.015381
# workclass-cat_Government           -0.015381                  1.000000
# workclass-cat_Private              -0.095430                 -0.684895
# workclass-cat_Unemployed           -0.014794                 -0.008781
# education-cat_Bachelors             0.075358                  0.057376
# education-cat_HS-dropout           -0.122074                 -0.084920
# education-cat_HS-grad               0.006228                 -0.075646
# education-cat_Some-college         -0.051178                  0.005712
# marital-cat_Single/Unmarried       -0.223890                 -0.009577
# occupation-cat_Manual               0.006805                 -0.077283
# occupation-cat_Military            -0.000387                  0.042430
# occupation-cat_Service             -0.184712                  0.016801
# occupation-cat_White-collar         0.125183                  0.151248
# relationship_Not-in-family          0.007298                  0.013110
# relationship_Other-relative        -0.052027                 -0.024423
# relationship_Own-child             -0.263296                 -0.052941
# relationship_Unmarried             -0.043330                  0.037570
# relationship_Wife                  -0.061065                  0.027433
# race_Asian-Pac-Islander            -0.006247                  0.003234
# race_Black                         -0.060493                  0.066981
# race_Other                         -0.006032                 -0.018374
# race_White                          0.056428                 -0.061118
# sex_Male                            0.231126                 -0.045899
# native_imm_cat_Native              -0.000389                  0.001651
# target                              0.229435                  0.054867
#
#                               workclass-cat_Private  workclass-cat_Unemployed  \
# age                                       -0.210427                  0.015340
# capital-gain                              -0.048138                 -0.001760
# capital-loss                              -0.036302                 -0.004714
# hours-per-week                            -0.095430                 -0.014794
# workclass-cat_Government                  -0.684895                 -0.008781
# workclass-cat_Private                      1.000000                 -0.036247
# workclass-cat_Unemployed                  -0.036247                  1.000000
# education-cat_Bachelors                   -0.054952                 -0.009663
# education-cat_HS-dropout                   0.086440                 -0.003436
# education-cat_HS-grad                      0.065642                  0.014556
# education-cat_Some-college                 0.013939                 -0.000583
# marital-cat_Single/Unmarried               0.127310                 -0.004505
# occupation-cat_Manual                      0.003633                  0.032795
# occupation-cat_Military                   -0.029060                 -0.000373
# occupation-cat_Service                     0.045819                 -0.003770
# occupation-cat_White-collar               -0.162569                 -0.013995
# relationship_Not-in-family                 0.032637                 -0.012644
# relationship_Other-relative                0.041640                 -0.003758
# relationship_Own-child                     0.109700                  0.012692
# relationship_Unmarried                     0.013708                  0.002538
# relationship_Wife                         -0.020637                  0.017136
# race_Asian-Pac-Islander                   -0.002852                  0.005307
# race_Black                                 0.004876                 -0.001630
# race_Other                                 0.028887                 -0.001895
# race_White                                -0.005322                 -0.000162
# sex_Male                                  -0.066726                 -0.001514
# native_imm_cat_Native                     -0.005991                  0.004973
# target                                    -0.117137                 -0.012415
#
#                               education-cat_Bachelors  \
# age                                          0.006877
# capital-gain                                 0.038892
# capital-loss                                 0.032772
# hours-per-week                               0.075358
# workclass-cat_Government                     0.057376
# workclass-cat_Private                       -0.054952
# workclass-cat_Unemployed                    -0.009663
# education-cat_Bachelors                      1.000000
# education-cat_HS-dropout                    -0.168604
# education-cat_HS-grad                       -0.311928
# education-cat_Some-college                  -0.292091
# marital-cat_Single/Unmarried                -0.044105
# occupation-cat_Manual                       -0.091724
# occupation-cat_Military                     -0.002601
# occupation-cat_Service                      -0.056210
# occupation-cat_White-collar                  0.296073
# relationship_Not-in-family                   0.057143
# relationship_Other-relative                 -0.035057
# relationship_Own-child                      -0.062692
# relationship_Unmarried                      -0.061999
# relationship_Wife                            0.015086
# race_Asian-Pac-Islander                      0.053678
# race_Black                                  -0.051954
# race_Other                                  -0.015947
# race_White                                   0.028453
# sex_Male                                     0.021638
# native_imm_cat_Native                        0.007597
# target                                       0.178902
#
#                               education-cat_HS-dropout  education-cat_HS-grad  \
# age                                          -0.009502               0.010709
# capital-gain                                 -0.041055              -0.047256
# capital-loss                                 -0.032291              -0.030296
# hours-per-week                               -0.122074               0.006228
# workclass-cat_Government                     -0.084920              -0.075646
# workclass-cat_Private                         0.086440               0.065642
# workclass-cat_Unemployed                     -0.003436               0.014556
# education-cat_Bachelors                      -0.168604              -0.311928
# education-cat_HS-dropout                      1.000000              -0.261782
# education-cat_HS-grad                        -0.261782               1.000000
# education-cat_Some-college                   -0.245135              -0.453515
# marital-cat_Single/Unmarried                  0.043861               0.002005
# occupation-cat_Manual                         0.145157               0.062300
# occupation-cat_Military                      -0.000674               0.004356
# occupation-cat_Service                       -0.003730               0.033553
# occupation-cat_White-collar                  -0.204740              -0.268174
# relationship_Not-in-family                   -0.042042              -0.027404
# relationship_Other-relative                   0.068317               0.026739
# relationship_Own-child                        0.075950              -0.011736
# relationship_Unmarried                        0.015001               0.041124
# relationship_Wife                            -0.028783              -0.001933
# race_Asian-Pac-Islander                      -0.021258              -0.041171
# race_Black                                    0.038031               0.034570
# race_Other                                    0.048912              -0.005171
# race_White                                   -0.037122              -0.012183
# sex_Male                                      0.020101               0.012822
# native_imm_cat_Native                        -0.001770               0.006673
# target                                       -0.164241              -0.136331
#
#                               ...  relationship_Own-child  \
# age                           ...               -0.420651
# capital-gain                  ...               -0.052365
# capital-loss                  ...               -0.050845
# hours-per-week                ...               -0.263296
# workclass-cat_Government      ...               -0.052941
# workclass-cat_Private         ...                0.109700
# workclass-cat_Unemployed      ...                0.012692
# education-cat_Bachelors       ...               -0.062692
# education-cat_HS-dropout      ...                0.075950
# education-cat_HS-grad         ...               -0.011736
# education-cat_Some-college    ...                0.070044
# marital-cat_Single/Unmarried  ...                0.374603
# occupation-cat_Manual         ...                0.074593
# occupation-cat_Military       ...               -0.001797
# occupation-cat_Service        ...                0.147899
# occupation-cat_White-collar   ...               -0.135818
# relationship_Not-in-family    ...               -0.244493
# relationship_Other-relative   ...               -0.072674
# relationship_Own-child        ...                1.000000
# relationship_Unmarried        ...               -0.143950
# relationship_Wife             ...               -0.092214
# race_Asian-Pac-Islander       ...                0.006964
# race_Black                    ...                0.021218
# race_Other                    ...               -0.005569
# race_White                    ...               -0.019964
# sex_Male                      ...               -0.102213
# native_imm_cat_Native         ...                0.002863
# target                        ...               -0.226237
#
#                               relationship_Unmarried  relationship_Wife  \
# age                                         0.049758           0.024525
# capital-gain                               -0.028824           0.015568
# capital-loss                               -0.040967           0.014945
# hours-per-week                             -0.043330          -0.061065
# workclass-cat_Government                    0.037570           0.027433
# workclass-cat_Private                       0.013708          -0.020637
# workclass-cat_Unemployed                    0.002538           0.017136
# education-cat_Bachelors                    -0.061999           0.015086
# education-cat_HS-dropout                    0.015001          -0.028783
# education-cat_HS-grad                       0.041124          -0.001933
# education-cat_Some-college                  0.019243          -0.000037
# marital-cat_Single/Unmarried                0.323341          -0.236244
# occupation-cat_Manual                      -0.027370          -0.043854
# occupation-cat_Military                    -0.005968          -0.003823
# occupation-cat_Service                      0.095648           0.044499
# occupation-cat_White-collar                -0.028266           0.058608
# relationship_Not-in-family                 -0.202531          -0.129741
# relationship_Other-relative                -0.060201          -0.038565
# relationship_Own-child                     -0.143950          -0.092214
# relationship_Unmarried                      1.000000          -0.076387
# relationship_Wife                          -0.076387           1.000000
# race_Asian-Pac-Islander                    -0.009031           0.013256
# race_Black                                  0.147798           0.000882
# race_Other                                  0.012811           0.000404
# race_White                                 -0.130277          -0.008975
# sex_Male                                   -0.326414          -0.318995
# native_imm_cat_Native                      -0.000200          -0.004886
# target                                     -0.145894           0.125092
#
#                               race_Asian-Pac-Islander  race_Black  race_Other  \
# age                                         -0.007847   -0.014038   -0.032393
# capital-gain                                 0.005026   -0.021141   -0.000382
# capital-loss                                 0.001447   -0.025522   -0.008289
# hours-per-week                              -0.006247   -0.060493   -0.006032
# workclass-cat_Government                     0.003234    0.066981   -0.018374
# workclass-cat_Private                       -0.002852    0.004876    0.028887
# workclass-cat_Unemployed                     0.005307   -0.001630   -0.001895
# education-cat_Bachelors                      0.053678   -0.051954   -0.015947
# education-cat_HS-dropout                    -0.021258    0.038031    0.048912
# education-cat_HS-grad                       -0.041171    0.034570   -0.005171
# education-cat_Some-college                  -0.014746    0.013606   -0.009031
# marital-cat_Single/Unmarried                -0.009545    0.125344    0.012137
# occupation-cat_Manual                       -0.022412    0.003140    0.008332
# occupation-cat_Military                     -0.003022    0.001050   -0.001519
# occupation-cat_Service                       0.011780    0.079487    0.001178
# occupation-cat_White-collar                  0.031660   -0.076864   -0.022067
# relationship_Not-in-family                  -0.019189    0.003201   -0.000980
# relationship_Other-relative                  0.048120    0.042408    0.040894
# relationship_Own-child                       0.006964    0.021218   -0.005569
# relationship_Unmarried                      -0.009031    0.147798    0.012811
# relationship_Wife                            0.013256    0.000882    0.000404
# race_Asian-Pac-Islander                      1.000000   -0.056130   -0.015366
# race_Black                                  -0.056130    1.000000   -0.028214
# race_Other                                  -0.015366   -0.028214    1.000000
# race_White                                  -0.432890   -0.794852   -0.217594
# sex_Male                                    -0.001716   -0.118332   -0.009830
# native_imm_cat_Native                       -0.007317    0.001622    0.005024
# target                                       0.011465   -0.088394   -0.032137
#
#                               race_White  sex_Male  native_imm_cat_Native  \
# age                             0.027281  0.081827               0.001417
# capital-gain                    0.016955  0.048819               0.007255
# capital-loss                    0.026230  0.047008              -0.000608
# hours-per-week                  0.056428  0.231126              -0.000389
# workclass-cat_Government       -0.061118 -0.045899               0.001651
# workclass-cat_Private          -0.005322 -0.066726              -0.005991
# workclass-cat_Unemployed       -0.000162 -0.001514               0.004973
# education-cat_Bachelors         0.028453  0.021638               0.007597
# education-cat_HS-dropout       -0.037122  0.020101              -0.001770
# education-cat_HS-grad          -0.012183  0.012822               0.006673
# education-cat_Some-college     -0.003758 -0.068153              -0.008729
# marital-cat_Single/Unmarried   -0.108153 -0.436671               0.008135
# occupation-cat_Manual           0.003270  0.113866              -0.006463
# occupation-cat_Military        -0.004080  0.011972              -0.003217
# occupation-cat_Service         -0.071116 -0.289711               0.007002
# occupation-cat_White-collar     0.058219 -0.011543              -0.002404
# relationship_Not-in-family      0.007201 -0.171948               0.005414
# relationship_Other-relative    -0.070772 -0.040942               0.001458
# relationship_Own-child         -0.019964 -0.102213               0.002863
# relationship_Unmarried         -0.130277 -0.326414              -0.000200
# relationship_Wife              -0.008975 -0.318995              -0.004886
# race_Asian-Pac-Islander        -0.432890 -0.001716              -0.007317
# race_Black                     -0.794852 -0.118332               0.001622
# race_Other                     -0.217594 -0.009830               0.005024
# race_White                      1.000000  0.105397               0.001139
# sex_Male                        0.105397  1.000000              -0.001894
# native_imm_cat_Native           0.001139 -0.001894               1.000000
# target                          0.084781  0.216668               0.003721
#
#                                 target
# age                           0.242017
# capital-gain                  0.221204
# capital-loss                  0.150026
# hours-per-week                0.229435
# workclass-cat_Government      0.054867
# workclass-cat_Private        -0.117137
# workclass-cat_Unemployed     -0.012415
# education-cat_Bachelors       0.178902
# education-cat_HS-dropout     -0.164241
# education-cat_HS-grad        -0.136331
# education-cat_Some-college   -0.050727
# marital-cat_Single/Unmarried -0.446021
# occupation-cat_Manual        -0.116737
# occupation-cat_Military      -0.005513
# occupation-cat_Service       -0.153870
# occupation-cat_White-collar   0.302302
# relationship_Not-in-family   -0.193066
# relationship_Other-relative  -0.084526
# relationship_Own-child       -0.226237
# relationship_Unmarried       -0.145894
# relationship_Wife             0.125092
# race_Asian-Pac-Islander       0.011465
# race_Black                   -0.088394
# race_Other                   -0.032137
# race_White                    0.084781
# sex_Male                      0.216668
# native_imm_cat_Native         0.003721
# target                        1.000000
#
# [28 rows x 28 columns]

# %%
# Convert to pairs of correlations
corr_pairs = corr.unstack()

# Sort by absolute value, descending
corr_pairs_sorted = corr_pairs.abs().sort_values(ascending=False)
corr_pairs_sorted = corr_pairs_sorted[corr_pairs_sorted < 0.999]  

corr_pairs_sorted
# Out:
# race_White                    race_Black                    0.794852
# race_Black                    race_White                    0.794852
# workclass-cat_Private         workclass-cat_Government      0.684895
# workclass-cat_Government      workclass-cat_Private         0.684895
# marital-cat_Single/Unmarried  relationship_Not-in-family    0.547048
#                                                               ...
# relationship_Unmarried        native_imm_cat_Native         0.000200
# workclass-cat_Unemployed      race_White                    0.000162
# race_White                    workclass-cat_Unemployed      0.000162
# education-cat_Some-college    relationship_Wife             0.000037
# relationship_Wife             education-cat_Some-college    0.000037
# Length: 756, dtype: float64

# %%
high_corr = corr_pairs_sorted[corr_pairs_sorted > 0.5]
high_corr
# Out:
# race_White                    race_Black                      0.794852
# race_Black                    race_White                      0.794852
# workclass-cat_Private         workclass-cat_Government        0.684895
# workclass-cat_Government      workclass-cat_Private           0.684895
# marital-cat_Single/Unmarried  relationship_Not-in-family      0.547048
# relationship_Not-in-family    marital-cat_Single/Unmarried    0.547048
# dtype: float64

# %%
# Convert pred to binary
train_df['target'] = train_df['pred'].apply(lambda x: 1 if x == '>50K' else 0)

# One-hot encode ALL features except target
encoded = pd.get_dummies(train_df.drop(columns=['pred']), drop_first=True)

# Compute correlation with target only
corr_target = encoded.corr()['target'].sort_values(ascending=False)

corr_target
# Out:
# target                          1.000000
# occupation-cat_White-collar     0.302302
# age                             0.242017
# hours-per-week                  0.229435
# capital-gain                    0.221204
# sex_Male                        0.216668
# education-cat_Bachelors         0.178902
# capital-loss                    0.150026
# relationship_Wife               0.125092
# race_White                      0.084781
# workclass-cat_Government        0.054867
# race_Asian-Pac-Islander         0.011465
# native_imm_cat_Native           0.003721
# occupation-cat_Military        -0.005513
# workclass-cat_Unemployed       -0.012415
# race_Other                     -0.032137
# education-cat_Some-college     -0.050727
# relationship_Other-relative    -0.084526
# race_Black                     -0.088394
# occupation-cat_Manual          -0.116737
# workclass-cat_Private          -0.117137
# education-cat_HS-grad          -0.136331
# relationship_Unmarried         -0.145894
# occupation-cat_Service         -0.153870
# education-cat_HS-dropout       -0.164241
# relationship_Not-in-family     -0.193066
# relationship_Own-child         -0.226237
# marital-cat_Single/Unmarried   -0.446021
# Name: target, dtype: float64

# %%
plt.figure(figsize=(6,10))
sns.heatmap(corr_target.to_frame(), annot=True, cmap='coolwarm')
plt.title("Correlation of Each Feature with Target")
plt.show()

# %%
# Remove native-country
encoded_filtered = encoded.drop(columns=[col for col in encoded.columns 
                                         if col.startswith("native-country_")])

# Remove numeric columns
numeric_cols = ['age', 'fnlwgt', 'education-num', 'capital-gain',
                'capital-loss', 'hours-per-week', 'target']  
encoded_filtered = encoded_filtered.drop(columns=[col for col in numeric_cols 
                                                  if col in encoded_filtered.columns])

# Compute correlation with target only (SORTED DESCENDING)
corr_target_only = encoded_filtered.join(train_df['target']) \
                                   .corr()['target'] \
                                   .sort_values(ascending=False)

# %%
plt.figure(figsize=(6, 20))
sns.heatmap(corr_target_only.to_frame(),
            annot=True,
            cmap='coolwarm',
            vmin=-0.4,
            vmax=0.45)
plt.title("Categorical Feature Correlations With Target")
plt.show()

# %%
# Full correlation matrix among remaining categorical columns
cat_corr_matrix = encoded_filtered.corr()

# %%
plt.figure(figsize=(22, 20))
sns.heatmap(cat_corr_matrix, cmap='coolwarm', center=0)
plt.title("Correlation Matrix of Categorical Features")
plt.show()
